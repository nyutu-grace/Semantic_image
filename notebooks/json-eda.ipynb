# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('../data/concepts.json')

# %%
df.head()
# Out:
#                      concept  \
# 0    Escape Challenge Teaser
# 1   Interactive Storytelling
# 2                  City Tour
# 3  Interactive Globe Journey
# 4          Cultural Carousel
#
#                                       implementation  \
# 0  {'frame_1': {'description': 'The ad begins wit...
# 1  {'frame_1': {'description': 'The ad opens with...
# 2  {'frame_1': {'description': 'The ad begins wit...
# 3  {'frame_1': {'description': 'The ad opens with...
# 4  {'frame_1': {'description': 'A carousel of cul...
#
#                                          explanation  \
# 0  This concept aligns with LEGO CITY's brand ide...
# 1  This concept aligns with LEGO CITY's brand ide...
# 2  This concept aligns with LEGO CITY's brand ide...
# 3  This concept aligns with the brand's identity ...
# 4  This concept leverages the brand's diverse por...
#
#                                    asset_suggestions
# 0  [{'frame_1': {'Background Animation': 'A suspe...
# 1  [{'frame_1': {'Background Animation': 'A suspe...
# 2  [{'frame_1': {'Background Animation': 'A suspe...
# 3  [{'frame_1': {'3D Globe': 'A high-definition 3...
# 4  [{'frame_1': {'Background Image': 'A high-reso...

# %%
df.shape
# Out:
# (115, 4)

# %%
df.describe()
# Out:
#                                                   concept  \
# count                                                 115
# unique                                                 99
# top     The ad begins with a captivating image of the ...
# freq                                                    5
#
#                                            implementation  \
# count                                                 115
# unique                                                111
# top     {'frame_1': {'description': 'The ad opens with...
# freq                                                    5
#
#                                               explanation  \
# count                                                 115
# unique                                                103
# top     This concept aligns with Adludio's brand ident...
# freq                                                    5
#
#                                         asset_suggestions
# count                                                 115
# unique                                                103
# top     [{'frame_1': {'Background Animation': 'A suspe...
# freq                                                   13

# %%
df['implementation'].apply(pd.Series)
# Out:
#                                                frame_1  \
# 0    {'description': 'The ad begins with a suspense...
# 1    {'description': 'The ad opens with a LEGO CITY...
# 2    {'description': 'The ad begins with a bird's-e...
# 3    {'description': 'The ad opens with a beautiful...
# 4    {'description': 'A carousel of cultural icons ...
# ..                                                 ...
# 110  {'description': 'The first frame presents a ga...
# 111  {'description': 'The first frame presents the ...
# 112  {'description': 'The first frame presents a ga...
# 113  {'description': 'The ad begins with a challeng...
# 114  {'description': 'The ad starts with a journey,...
#
#                                                frame_2  \
# 0    {'description': 'The scene transitions to a se...
# 1    {'description': 'Depending on the user's choic...
# 2    {'description': 'The scene transitions to a fi...
# 3    {'description': 'Upon swiping, the globe spins...
# 4    {'description': 'Each swipe reveals a new dest...
# ..                                                 ...
# 110  {'description': 'The second frame simulates th...
# 111  {'description': 'The second frame provides a 3...
# 112  {'description': 'The second frame simulates th...
# 113  {'description': 'The user solves the puzzles, ...
# 114  {'description': 'The user navigates through a ...
#
#                                                frame_3  \
# 0    {'description': 'The final frame reveals the L...
# 1    {'description': 'The story concludes with a cl...
# 2    {'description': 'The tour concludes with a vie...
# 3    {'description': 'The scene transitions to a 't...
# 4    {'description': 'A 'Discover More' button appe...
# ..                                                 ...
# 110  {'description': 'The third frame concludes the...
# 111  {'description': 'The third frame provides deta...
# 112  {'description': 'The third frame concludes the...
# 113  {'description': 'Upon solving the puzzles, the...
# 114  {'description': 'Upon reaching the destination...
#
#                                                frame_4 end-of-advertisement  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    {'description': 'The final frame showcases a '...                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 110                                                NaN                  NaN
# 111                                                NaN                  NaN
# 112                                                NaN                  NaN
# 113  {'description': 'The ad concludes with the bra...                  NaN
# 114  {'description': 'The ad concludes with the bra...                  NaN
#
#     frame_5 frame_6 frame_7
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# 3       NaN     NaN     NaN
# 4       NaN     NaN     NaN
# ..      ...     ...     ...
# 110     NaN     NaN     NaN
# 111     NaN     NaN     NaN
# 112     NaN     NaN     NaN
# 113     NaN     NaN     NaN
# 114     NaN     NaN     NaN
#
# [115 rows x 8 columns]

# %%
df['asset_suggestions'].apply(pd.Series)
# Out:
#                                                      0  \
# 0    {'frame_1': {'Background Animation': 'A suspen...
# 1    {'frame_1': {'Background Animation': 'A suspen...
# 2    {'frame_1': {'Background Animation': 'A suspen...
# 3    {'frame_1': {'3D Globe': 'A high-definition 3D...
# 4    {'frame_1': {'Background Image': 'A high-resol...
# ..                                                 ...
# 110  {'frame_1': {'Background Image': 'A high-resol...
# 111  {'frame_1': {'Product Image': 'A high-resoluti...
# 112  {'frame_1': {'Background Image': 'A high-resol...
# 113  {'frame_1': {'Background': 'A dark, mysterious...
# 114  {'frame_1': {'Background': 'A dark, star-studd...
#
#                                                      1  \
# 0    {'frame_1': {'Background': 'A lively, animated...
# 1    {'frame_1': {'Background': 'A lively, animated...
# 2    {'frame_1': {'Background': 'A lively, animated...
# 3    {'frame_1': {'3D Globe': 'A photorealistic 3D ...
# 4    {'frame_1': {'Background Image': 'A high-resol...
# ..                                                 ...
# 110  {'frame_1': {'Background Image': 'An image of ...
# 111  {'frame_1': {'Product Image': 'A close-up imag...
# 112  {'frame_1': {'Background Image': 'A sleek imag...
# 113  {'frame_1': {'Background': 'A sleek, metallic ...
# 114  {'frame_1': {'Background': 'A sleek, metallic ...
#
#                                                      2  \
# 0    {'frame_1': {'Background': 'A vibrant, detaile...
# 1    {'frame_1': {'Background': 'A vibrant, detaile...
# 2    {'frame_1': {'Background': 'A vibrant, detaile...
# 3    {'frame_1': {'3D Globe': 'A 3D globe, rendered...
# 4    {'frame_1': {'Background Image': 'A high-resol...
# ..                                                 ...
# 110  {'frame_1': {'Background Image': 'A dramatic i...
# 111  {'frame_1': {'Product Image': 'An image of the...
# 112  {'frame_1': {'Background Image': 'An image of ...
# 113  {'frame_1': {'Background': 'A classy, silver b...
# 114  {'frame_1': {'Background': 'A dark, star-studd...
#
#                                                      3  \
# 0    {'frame_1': {'Background': 'A vibrant, bustlin...
# 1    {'frame_1': {'Background': 'A vibrant, bustlin...
# 2    {'frame_1': {'Background': 'A vibrant, bustlin...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
#
#                                                      4
# 0    {'frame_1': {'Background': 'A vibrant, bustlin...
# 1    {'frame_1': {'Background': 'A vibrant, bustlin...
# 2    {'frame_1': {'Background': 'A vibrant, bustlin...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
#
# [115 rows x 5 columns]
